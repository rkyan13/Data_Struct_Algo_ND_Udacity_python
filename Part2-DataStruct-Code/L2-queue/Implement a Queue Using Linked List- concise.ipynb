# %% [markdown]
# # Implement a Queue Using Linked List- concise

# %%
class Node():
    def __init__(self,value= None):
        self.value = value
        self.next  = None
    
    def set_value(self, value):
        self.value = value
    
    def get_value(self):
        return self.value
    
    def set_next(self, next):
        self.next = next
    
    def get_next(self):
        return self.next

    
    
class LinkedList():
    def __init__(self):
        self.head = None
        self.tail = self.head
        
        
    #Insert value at tail end    
    def append(self, value):     
        node      = Node(value)
        #if this is the very first element
        if(self.head == None):            
            self.head = node
            self.tail = node
        else
            self.tail.next = node
            self.tail      = node
    
    #Insert Value at head end
    def prepend(self,value):
        node      = Node(value)        
        #if this is the very first element
        if(self.head == None):            
            self.head = node
            self.tail = node
        else
            node.set_next(self.head)
            self.head = node
        
    #Delete value at head end
    def delete_at_head(self):
        value = self.head.value
        self.head = self.head.next
        return value
    
    #Delete value at tail end
    def delete_at_tail(self):

        
        #It means that there are no nodes(empty linked list), or only one Node i.e. head
        if(self.head.next == None):
            #If there are no nodes value =None. If head is the only value, value = self.head.value
            value = self.head.value
            self.head = None
            self.tail = None
        else:
            value = self.tail.value
            prev_ptr = self.head
            curr_ptr = self.head.next
            
        #When curr_ptr.next == None , it means curr_ptr is the tail
        while(curr_ptr.next!= None):
            prev_ptr = curr_ptr
            curr_ptr = curr_ptr.next
        
        #Move the tail to the previous-pointer
        self.tail      = prev_ptr
        self.tail.next = None
        return value
    
    #return the value of a node by its position in the linked list
    #Note: head = pos#0
    def return_value(self, position):
        idx = 0
        curr_ptr = self.head
        while(curr_ptr !=None)
